# %% [markdown]
# <a href="https://colab.research.google.com/github/ho891/ABCD-A/blob/20250331/%ED%8C%8C%EC%9D%B4%EC%8D%AC_%EB%B2%A1%ED%84%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x1 = float(input("첫 번째 벡터의 x 성분을 입력하세요: "))
y1 = float(input("첫 번째 벡터의 y 성분을 입력하세요: "))

x2 = float(input("두 번째 벡터의 x 성분을 입력하세요: "))
y2 = float(input("두 번째 벡터의 y 성분을 입력하세요: "))

sum_x = x1 + x2
sum_y = y1 + y2

dot_product = sum_x * sum_y
cross_product = sum_x * y2 - sum_y * x2

print("\n벡터 1:", x1, "i +", y1, "j")
print("벡터 2:", x2, "i +", y2, "j")

print("\n벡터의 합:", sum_x, "i +", sum_y, "j")
print("벡터의 내적:", dot_product)
print("벡터의 외적:", cross_product)
# Out:
# 첫 번째 벡터의 x 성분을 입력하세요: 9
# 첫 번째 벡터의 y 성분을 입력하세요: 8
# 두 번째 벡터의 x 성분을 입력하세요: 7
# 두 번째 벡터의 y 성분을 입력하세요: 6
#
# 벡터 1: 9.0 i + 8.0 j
# 벡터 2: 7.0 i + 6.0 j
#
# 벡터의 합: 16.0 i + 14.0 j
# 벡터의 내적: 224.0
# 벡터의 외적: -2.0

# %%
x1 = float(input("첫 번째 벡터의 x 성분을 입력하세요: "))
y1 = float(input("첫 번째 벡터의 y 성분을 입력하세요: "))
z1 = float(input("첫 번째 벡터의 z 성분을 입력하세요: "))

x2 = float(input("두 번째 벡터의 x 성분을 입력하세요: "))
y2 = float(input("두 번째 벡터의 y 성분을 입력하세요: "))
z2 = float(input("두 번째 벡터의 z 성분을 입력하세요: "))

sum_x = x1 + x2
sum_y = y1 + y2
sum_z = z1 + z2

dot_product = sum_x * sum_y + sum_z * (x1 + x2)
cross_product_x = sum_y * z2 - sum_z * y2
cross_product_y = sum_z * x2 - sum_x * z2
cross_product_z = sum_x * y2 - sum_y * x2

print("\n벡터 1:", x1, "i +", y1, "j +", z1, "k")
print("벡터 2:", x2, "i +", y2, "j +", z2, "k")

print("\n벡터의 합:", sum_x, "i +", sum_y, "j +", sum_z, "k")
print("벡터의 내적:", dot_product)
print("벡터의 외적:", cross_product_x, "i +", cross_product_y, "j +", cross_product_z, "k")
# Out:
# 첫 번째 벡터의 x 성분을 입력하세요: 6
# 첫 번째 벡터의 y 성분을 입력하세요: 7
# 첫 번째 벡터의 z 성분을 입력하세요: 4
# 두 번째 벡터의 x 성분을 입력하세요: 3
# 두 번째 벡터의 y 성분을 입력하세요: 8
# 두 번째 벡터의 z 성분을 입력하세요: 7
#
# 벡터 1: 6.0 i + 7.0 j + 4.0 k
# 벡터 2: 3.0 i + 8.0 j + 7.0 k
#
# 벡터의 합: 9.0 i + 15.0 j + 11.0 k
# 벡터의 내적: 234.0
# 벡터의 외적: 17.0 i + -30.0 j + 27.0 k
